# %%
import mysql.connector
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Establishing a connection to the MySQL database
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="qwerty1234",
    database="finance_database"
)

# Defining the SQL query and reading the results into DataFrame
query = "SELECT * FROM TABLE_NAME"
df = pd.read_sql_query(query, connection)
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_18096\1872617786.py:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)

# %%
df.head()
# Out:
#    gender   age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female  34.0                Yes           1.0            2.0         5.0
# 1  Female  23.0                Yes           4.0            3.0         2.0
# 2    Male  30.0                Yes           3.0            6.0         4.0
# 3    Male  22.0                Yes           2.0            1.0         3.0
# 4  Female  24.0                 No           2.0            1.0         3.0
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0               3.0             7.0  6.0   4.0  ...          1-3 years
# 1               1.0             5.0  6.0   7.0  ...  More than 5 years
# 2               2.0             5.0  1.0   7.0  ...          3-5 years
# 3               7.0             6.0  4.0   5.0  ...   Less than 1 year
# 4               6.0             4.0  5.0   7.0  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue Savings_Objectives  \
# ...

# %%
df.describe()
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %%
# Plotting the count of genders
plt.figure(figsize=(5,3))
sns.countplot(data=df, x='gender')
plt.title('Gender Distribution', fontsize=14)
plt.xlabel('Gender', fontsize=12)  
plt.ylabel('Count', fontsize=12)  
plt.show()

# %%
# Plotting a histogram of ages
sns.histplot(data=df, x='age', bins=10)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Plotting a box plot of investment avenues
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['Mutual_Funds', 'Equity_Market', 'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold']])
plt.title('Investment Avenues', fontsize=16)
plt.xlabel('Avenue', fontsize=14)
plt.ylabel('Amount', fontsize=14)
plt.tight_layout()
plt.show()

# %%
# Duration Analysis
duration_counts = df["Duration"].value_counts()
duration_counts.plot(kind="bar", rot=0)
plt.xlabel("Duration")
plt.ylabel("Count")
plt.title("Preferred Investment Durations")
plt.show()

# %%
# Monitoring Frequency using bar graph
plt.figure(figsize=(6,3))
monitoring_counts = df["Invest_Monitor"].value_counts()
monitoring_counts.plot(kind="bar", rot=0)
plt.xlabel("Monitoring Frequency")
plt.ylabel("Count")
plt.title("Investment Monitoring Frequency")
plt.show()
